# %% [markdown]
# ## COVID Information Detection

# %% [markdown]
# As **COVID-19** continues to spread across the country and the world, we all must remain vigilant. The changes we have had to make to routines and daily life are extremely hard, but these changes are even more important now and in the future. We must stop the spread of this new and dangerous virus. The more steps you and your family can take to prevent the spread of COVID-19, the safer you will be.
#
# The way this pandemic is spreading, it is creating havoc and there are certain myths and rumors related to thes disease. Sometimes a lot of information can also be misguiding. As part of an effort to **combat misinformation** about coronavirus, we are trying to classify the given dataset by binary classification, in which we will predict on the basis of the information trained, whether the information is Fake or True. This will help common citizens to identify the news related to the pandemic.
#
# ![Countries cases distribution](covid_cases.png)
#
# Image courtesy : https://www.worldometers.info/coronavirus/worldwide-graphs/#case-distribution

# %% [markdown]
# ### Importing libraries

# %%
# !pip3 install textstat
# !pip3 install lexicalrichness
# !pip3 install textblob
# !pip3 install plotly
from nltk.corpus import stopwords    
stop_words = set(stopwords.words('english'))

from nltk.tag import pos_tag
from nltk import word_tokenize
from collections import Counter

import textstat
from lexicalrichness import LexicalRichness

import plotly.express as px
import plotly.figure_factory as ff
import plotly.graph_objects as go

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix  
from sklearn.metrics import accuracy_score
from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score

import pandas as pd
import numpy as np

# %%
df = pd.read_csv('corona_fake.csv')
df
# Out:
#                                                   title  \
# 0     Due to the recent outbreak for the Coronavirus...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1159   Could the Power of the Sun Slow the Coronavirus?
# 1160  Key evidence for coronavirus spread is flawed ...
# 1161  Summer Heat May Not Diminish Coronavirus Strength
# 1162               How Long Will a Vaccine Really Take?
# 1163  Why Funding the Covid-19 Response Could Be the...
#
#                                                    text  \
# 0     You just need to add water, and the drugs and ...
# 1     Hydroxychloroquine has been shown to have a 10...
# 2     Fact: Hydroxychloroquine has been shown to hav...
# 3     The Corona virus is a man made virus created i...
# 4     Doesn’t @BillGates finance research at the Wuh...
# ...                                                 ...
# 1159  A study suggests that ultraviolet rays could s...
# 1160  Last week, a medical journal reported that a b...
# 1161  A new report, sent to the White House science ...
# 1162  A vaccine would be the ultimate weapon against...
# 1163  Developing and delivering coronavirus vaccines...
#
#                          source label
# 0     coronavirusmedicalkit.com  Fake
# 1                  RudyGiuliani  Fake
# 2                   CharlieKirk  Fake
# 3       JoanneWrightForCongress  Fake
# 4       JoanneWrightForCongress  Fake
# ...                         ...   ...
# 1159   https://www.nytimes.com/  TRUE
# 1160   https://www.nytimes.com/  TRUE
# 1161   https://www.nytimes.com/  TRUE
# 1162   https://www.nytimes.com/  TRUE
# 1163   https://www.nytimes.com/  TRUE
#
# [1164 rows x 4 columns]

# %% [markdown]
# #### Dropping rows with NaN values

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum().sum()
# Out:
# 117

# %%
df.dropna()
# Out:
#                                                   title  \
# 0     Due to the recent outbreak for the Coronavirus...
# 9     Basic protective measures against the new coro...
# 14    Exposing yourself to the sun or to temperature...
# 16    Being able to hold your breath for 10 seconds ...
# 17    Drinking alcohol does not protect you against ...
# ...                                                 ...
# 1159   Could the Power of the Sun Slow the Coronavirus?
# 1160  Key evidence for coronavirus spread is flawed ...
# 1161  Summer Heat May Not Diminish Coronavirus Strength
# 1162               How Long Will a Vaccine Really Take?
# 1163  Why Funding the Covid-19 Response Could Be the...
#
#                                                    text  \
# 0     You just need to add water, and the drugs and ...
# 9     Stay aware of the latest information on the CO...
# 14    You can catch COVID-19, no matter how sunny or...
# 16    The most common symptoms of COVID-19 are dry c...
# 17    Frequent or excessive alcohol consumption can ...
# ...                                                 ...
# 1159  A study suggests that ultraviolet rays could s...
# 1160  Last week, a medical journal reported that a b...
# 1161  A new report, sent to the White House science ...
# 1162  A vaccine would be the ultimate weapon against...
# 1163  Developing and delivering coronavirus vaccines...
#
#                                                  source label
# 0                             coronavirusmedicalkit.com  Fake
# 9     https://www.who.int/emergencies/diseases/novel...  TRUE
# 14    https://www.who.int/emergencies/diseases/novel...  TRUE
# 16    https://www.who.int/emergencies/diseases/novel...  TRUE
# 17    https://www.who.int/emergencies/diseases/novel...  TRUE
# ...                                                 ...   ...
# 1159                           https://www.nytimes.com/  TRUE
# 1160                           https://www.nytimes.com/  TRUE
# 1161                           https://www.nytimes.com/  TRUE
# 1162                           https://www.nytimes.com/  TRUE
# 1163                           https://www.nytimes.com/  TRUE
#
# [1059 rows x 4 columns]

# %%
df.loc[df['label'] == 'Fake', ['label']] = 'FAKE'
df.loc[df['label'] == 'fake', ['label']] = 'FAKE'
df.loc[df['label'] == 'TRUE', ['label']] = 'GENUINE'
df.loc[df['label'] == 'True', ['label']] = 'GENUINE'
df.loc[df['source'] == 'facebook', ['source']] = 'Facebook'
df.text.fillna(df.title, inplace=True)

# %%
df.head(20)
# Out:
#                                                 title  \
# 0   Due to the recent outbreak for the Coronavirus...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   CORONA UNMASKED: Chinese Intelligence Officer ...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   Basic protective measures against the new coro...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  Exposing yourself to the sun or to temperature...
# 15  You can recover from the coronavirus disease (...
# 16  Being able to hold your breath for 10 seconds ...
# 17  Drinking alcohol does not protect you against ...
# 18  COVID-19 virus can be transmitted in areas wit...
# 19  Cold weather and snow CANNOT kill the new coro...
#
#                                                  text  \
# 0   You just need to add water, and the drugs and ...
# 1   Hydroxychloroquine has been shown to have a 10...
# 2   Fact: Hydroxychloroquine has been shown to hav...
# 3   The Corona virus is a man made virus created i...
# 4   Doesn’t @BillGates finance research at the Wuh...
# 5   CORONA UNMASKED: Chinese Intelligence Officer ...
# 6   Urgent: Health Bulletin to the Public. Ministr...
# 7   Pls tell ur families, relatives and friendsMOH...
# 8   SERIOUS EXCELLENT ADVICE by Japanese doctors t...
# 9   Stay aware of the latest information on the CO...
# 10  The new Coronavirus may not show signs of infe...
# 11  A vaccine meant for cattle can be used to figh...
# 12  Using a hair dryer to breathe in hot air can c...
# 13  Corona virus before it reaches the lungs it re...
# 14  You can catch COVID-19, no matter how sunny or...
# 15  Most of the people who catch COVID-19 can reco...
# 16  The most common symptoms of COVID-19 are dry c...
# 17  Frequent or excessive alcohol consumption can ...
# 18  From the evidence so far, the COVID-19 virus c...
# 19  There is no reason to believe that cold weathe...
#
#                                                source    label
# 0                           coronavirusmedicalkit.com     FAKE
# 1                                        RudyGiuliani     FAKE
# 2                                         CharlieKirk     FAKE
# 3                             JoanneWrightForCongress     FAKE
# 4                             JoanneWrightForCongress     FAKE
# 5                                                 NaN      NaN
# 6                                  Ministry of Health     FAKE
# 7                                              NWLLAB     FAKE
# 8            Japanese doctors treating COVID-19 cases     FAKE
# 9   https://www.who.int/emergencies/diseases/novel...  GENUINE
# 10                                     Taiwan Experts     FAKE
# 11                                           Facebook     FAKE
# 12                                            Youtube     FAKE
# 13                                            twitter     FAKE
# 14  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 15  https://www.who.int/emergencies/diseases/novel...      NaN
# 16  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 17  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 18  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 19  https://www.who.int/emergencies/diseases/novel...  GENUINE

# %%
# function to remove stopwords from the text
stop_words = set(stopwords.words('english'))


def remove_stopwords(text):
    no_stopword_text = [w for w in text.split() if not w in stop_words]
    return ' '.join(no_stopword_text)

# %%
'''
Preprocess a string text input.
:parameter
    :parameter text: - name of column containing text
    :param lst_stopwords: list - list of stopwords to remove
    :param flg_stemm: bool - whether stemming is to be applied
    :param flg_lemm: bool - whether lemmitisation is to be applied
:return
    cleaned text
'''
def func_preprocess_text(text, flg_stemm=False, flg_lemm=True, lst_stopwords=None):
    ## clean (convert to lowercase and remove punctuations and characters and then strip)
    text = re.sub(r'[^\w\s]', '', str(text).lower().strip())
            
    ## Tokenize 
    lst_text = text.split()
    ## remove Stopwords
    if lst_stopwords is not None:
        lst_text = [word for word in lst_text if word not in 
                    lst_stopwords]
                
    ## Stemming 
    if flg_stemm == True:
        ps = nltk.stem.porter.PorterStemmer()
        lst_text = [ps.stem(word) for word in lst_text]
                
    ## Lemmatisation 
    if flg_lemm == True:
        lem = nltk.stem.wordnet.WordNetLemmatizer()
        lst_text = [lem.lemmatize(word) for word in lst_text]
            
    ## back to string from list
    text = " ".join(lst_text)
    return text

# %%
import nltk
import re
df['text_clean'] = df['text'].apply(lambda x: func_preprocess_text(x))

# %%
df_text_clean = df.drop("text", axis=1)

# %%
df_text_clean
# Out:
#                                                   title  \
# 0     Due to the recent outbreak for the Coronavirus...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1159   Could the Power of the Sun Slow the Coronavirus?
# 1160  Key evidence for coronavirus spread is flawed ...
# 1161  Summer Heat May Not Diminish Coronavirus Strength
# 1162               How Long Will a Vaccine Really Take?
# 1163  Why Funding the Covid-19 Response Could Be the...
#
#                          source    label  \
# 0     coronavirusmedicalkit.com     FAKE
# 1                  RudyGiuliani     FAKE
# 2                   CharlieKirk     FAKE
# 3       JoanneWrightForCongress     FAKE
# 4       JoanneWrightForCongress     FAKE
# ...                         ...      ...
# 1159   https://www.nytimes.com/  GENUINE
# 1160   https://www.nytimes.com/  GENUINE
# 1161   https://www.nytimes.com/  GENUINE
# 1162   https://www.nytimes.com/  GENUINE
# 1163   https://www.nytimes.com/  GENUINE
#
#                                              text_clean
# 0     you just need to add water and the drug and va...
# 1     hydroxychloroquine ha been shown to have a 100...
# 2     fact hydroxychloroquine ha been shown to have ...
# 3     the corona virus is a man made virus created i...
# 4     doesnt billgates finance research at the wuhan...
# ...                                                 ...
# 1159  a study suggests that ultraviolet ray could sl...
# 1160  last week a medical journal reported that a bu...
# 1161  a new report sent to the white house science a...
# 1162  a vaccine would be the ultimate weapon against...
# 1163  developing and delivering coronavirus vaccine ...
#
# [1164 rows x 4 columns]

# %%
df_text_clean = df_text_clean[['title','text_clean','source','label']]
df_text_clean.head()
# Out:
#                                                title  \
# 0  Due to the recent outbreak for the Coronavirus...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           text_clean  \
# 0  you just need to add water and the drug and va...
# 1  hydroxychloroquine ha been shown to have a 100...
# 2  fact hydroxychloroquine ha been shown to have ...
# 3  the corona virus is a man made virus created i...
# 4  doesnt billgates finance research at the wuhan...
#
#                       source label
# 0  coronavirusmedicalkit.com  FAKE
# 1               RudyGiuliani  FAKE
# 2                CharlieKirk  FAKE
# 3    JoanneWrightForCongress  FAKE
# 4    JoanneWrightForCongress  FAKE

# %%
# Wordcloud of corona article text
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
text = df_text_clean.text_clean.values
wordcloud = WordCloud(
    width = 2000,
    height = 1000,
    background_color = 'white',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (20, 15),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
df_text_clean.isnull().sum().sum()
# Out:
# 107

# %%
df_text_clean=df_text_clean.dropna()

# %%
df_text_clean.head(20)
# Out:
#                                                 title  \
# 0   Due to the recent outbreak for the Coronavirus...
# 9   Basic protective measures against the new coro...
# 14  Exposing yourself to the sun or to temperature...
# 16  Being able to hold your breath for 10 seconds ...
# 17  Drinking alcohol does not protect you against ...
# 18  COVID-19 virus can be transmitted in areas wit...
# 19  Cold weather and snow CANNOT kill the new coro...
# 20  Taking a hot bath does not prevent the new cor...
# 21  The new coronavirus CANNOT be transmitted thro...
# 22  Are hand dryers effective in killing the new c...
# 23  Can an ultraviolet disinfection lamp kill the ...
# 24  How effective are thermal scanners in detectin...
# 25  Can spraying alcohol or chlorine all over your...
# 26  Do vaccines against pneumonia protect you agai...
# 27  Can regularly rinsing your nose with saline he...
# 28  Can eating garlic help prevent infection with ...
# 29  Does the new coronavirus affect older people, ...
# 30  Are antibiotics effective in preventing and tr...
# 31  Are there any specific medicines to prevent or...
# 32  Why Hand-Washing Really Is as Important as Doc...
#
#                                            text_clean  \
# 0   you just need to add water and the drug and va...
# 9   stay aware of the latest information on the co...
# 14  you can catch covid19 no matter how sunny or h...
# 16  the most common symptom of covid19 are dry cou...
# 17  frequent or excessive alcohol consumption can ...
# 18  from the evidence so far the covid19 virus can...
# 19  there is no reason to believe that cold weathe...
# 20  taking a hot bath will not prevent you from ca...
# 21  to date there ha been no information nor evide...
# 22  no hand dryer are not effective in killing the...
# 23  uv lamp should not be used to sterilize hand o...
# 24  thermal scanner are effective in detecting peo...
# 25  no spraying alcohol or chlorine all over your ...
# 26  no vaccine against pneumonia such a pneumococc...
# 27  no there is no evidence that regularly rinsing...
# 28  garlic is a healthy food that may have some an...
# 29  people of all age can be infected by the new c...
# 30  no antibiotic do not work against virus only b...
# 31  to date there is no specific medicine recommen...
# 32  washing your hand decrease the number of micro...
#
#                                                source    label
# 0                           coronavirusmedicalkit.com     FAKE
# 9   https://www.who.int/emergencies/diseases/novel...  GENUINE
# 14  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 16  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 17  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 18  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 19  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 20  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 21  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 22  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 23  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 24  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 25  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 26  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 27  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 28  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 29  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 30  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 31  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 32  https://www.snopes.com/news/2020/03/03/why-han...  GENUINE

# %%
df_text_clean['title_clean'] = df_text_clean['title'].apply(lambda x: func_preprocess_text(x))

# %%
final_df = df_text_clean.drop("title", axis=1)

# %%
final_df.head()
# Out:
#                                            text_clean  \
# 0   you just need to add water and the drug and va...
# 9   stay aware of the latest information on the co...
# 14  you can catch covid19 no matter how sunny or h...
# 16  the most common symptom of covid19 are dry cou...
# 17  frequent or excessive alcohol consumption can ...
#
#                                                source    label  \
# 0                           coronavirusmedicalkit.com     FAKE
# 9   https://www.who.int/emergencies/diseases/novel...  GENUINE
# 14  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 16  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 17  https://www.who.int/emergencies/diseases/novel...  GENUINE
#
#                                           title_clean
# 0   due to the recent outbreak for the coronavirus...
# 9   basic protective measure against the new coron...
# 14  exposing yourself to the sun or to temperature...
# 16  being able to hold your breath for 10 second o...
# 17  drinking alcohol doe not protect you against c...

# %%
final_df = final_df[['title_clean','text_clean','source','label']]
final_df.head()
# Out:
#                                           title_clean  \
# 0   due to the recent outbreak for the coronavirus...
# 9   basic protective measure against the new coron...
# 14  exposing yourself to the sun or to temperature...
# 16  being able to hold your breath for 10 second o...
# 17  drinking alcohol doe not protect you against c...
#
#                                            text_clean  \
# 0   you just need to add water and the drug and va...
# 9   stay aware of the latest information on the co...
# 14  you can catch covid19 no matter how sunny or h...
# 16  the most common symptom of covid19 are dry cou...
# 17  frequent or excessive alcohol consumption can ...
#
#                                                source    label
# 0                           coronavirusmedicalkit.com     FAKE
# 9   https://www.who.int/emergencies/diseases/novel...  GENUINE
# 14  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 16  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 17  https://www.who.int/emergencies/diseases/novel...  GENUINE

# %%
final_df.isnull().sum().sum()
# Out:
# 0

# %%
# Wordcloud of corona article title
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
text = final_df.title_clean.values
wordcloud = WordCloud(
    width = 2000,
    height = 1000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (20, 15),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
final_df['total']=final_df['text_clean']+' '+final_df['title_clean']
final_df.head()
# Out:
#                                           title_clean  \
# 0   due to the recent outbreak for the coronavirus...
# 9   basic protective measure against the new coron...
# 14  exposing yourself to the sun or to temperature...
# 16  being able to hold your breath for 10 second o...
# 17  drinking alcohol doe not protect you against c...
#
#                                            text_clean  \
# 0   you just need to add water and the drug and va...
# 9   stay aware of the latest information on the co...
# 14  you can catch covid19 no matter how sunny or h...
# 16  the most common symptom of covid19 are dry cou...
# 17  frequent or excessive alcohol consumption can ...
#
#                                                source    label  \
# 0                           coronavirusmedicalkit.com     FAKE
# 9   https://www.who.int/emergencies/diseases/novel...  GENUINE
# 14  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 16  https://www.who.int/emergencies/diseases/novel...  GENUINE
# 17  https://www.who.int/emergencies/diseases/novel...  GENUINE
#
#                                                 total
# 0   you just need to add water and the drug and va...
# 9   stay aware of the latest information on the co...
# 14  you can catch covid19 no matter how sunny or h...
# 16  the most common symptom of covid19 are dry cou...
# 17  frequent or excessive alcohol consumption can ...

# %% [markdown]
# ### Text to vector formation
#
# Text to vectorization, converting text into binary vectors that can be easily used to train machine learning models

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# list of text documents
text = final_df['title_clean'].tolist()

# create the transform
vectorizer = TfidfVectorizer()
# tokenize and build vocab
vectorizer.fit(text)
# summarize
print(vectorizer.vocabulary_)
print(vectorizer.idf_)
# encode document
vector = vectorizer.transform([text[0]])
# summarize encoded vector
print(vector.shape)
print(vector.toarray())
# Out:
# {'due': 605, 'to': 1956, 'the': 1930, 'recent': 1567, 'outbreak': 1364, 'for': 767, 'coronavirus': 417, 'covid19': 437, 'world': 2142, 'health': 892, 'organization': 1352, 'is': 1054, 'giving': 831, 'away': 161, 'vaccine': 2046, 'kit': 1090, 'just': 1078, 'pay': 1403, '495': 30, 'shipping': 1734, 'basic': 175, 'protective': 1518, 'measure': 1190, 'against': 76, 'new': 1288, 'exposing': 705, 'yourself': 2163, 'sun': 1872, 'or': 1348, 'temperature': 1917, 'higher': 912, 'than': 1926, '25c': 21, 'degree': 503, 'doe': 579, 'not': 1303, 'prevent': 1486, 'disease': 559, 'being': 193, 'able': 43, 'hold': 926, 'your': 2161, 'breath': 250, '10': 1, 'second': 1698, 'more': 1240, 'without': 2132, 'coughing': 422, 'feeling': 737, 'discomfort': 553, 'mean': 1188, 'you': 2159, 'are': 141, 'free': 784, 'from': 790, 'any': 127, 'other': 1358, 'lung': 1159, 'drinking': 598, 'alcohol': 92, 'protect': 1514, 'and': 114, 'can': 274, 'be': 179, 'dangerous': 476, 'virus': 2065, 'transmitted': 1986, 'in': 987, 'area': 142, 'with': 2131, 'hot': 936, 'humid': 947, 'climate': 345, 'cold': 359, 'weather': 2101, 'snow': 1776, 'cannot': 283, 'kill': 1085, 'taking': 1906, 'bath': 177, 'through': 1951, 'mosquito': 1242, 'bite': 223, 'hand': 869, 'dryer': 604, 'effective': 620, 'killing': 1088, 'an': 112, 'ultraviolet': 2016, 'disinfection': 563, 'lamp': 1100, 'how': 941, 'thermal': 1941, 'scanner': 1684, 'detecting': 524, 'people': 1405, 'infected': 1000, 'spraying': 1807, 'chlorine': 326, 'all': 95, 'over': 1368, 'body': 234, 'do': 575, 'pneumonia': 1444, 'regularly': 1588, 'rinsing': 1635, 'nose': 1302, 'saline': 1668, 'help': 900, 'infection': 1002, 'eating': 613, 'garlic': 809, 'affect': 71, 'older': 1333, 'younger': 2160, 'also': 101, 'susceptible': 1889, 'antibiotic': 121, 'preventing': 1488, 'treating': 1994, 'there': 1940, 'specific': 1800, 'medicine': 1194, 'treat': 1992, 'why': 2121, 'handwashing': 873, 'really': 1564, 'important': 984, 'doctor': 576, 'say': 1681, 'china': 324, 'seek': 1702, 'court': 428, 'approval': 136, '20000': 13, 'patient': 1401, 'avoid': 160, 'further': 804, 'spread': 1808, 'of': 1322, 'did': 534, 'originate': 1355, 'chinese': 325, 'government': 842, 'laboratory': 1098, 'scientist': 1693, 'believe': 196, 'killer': 1087, 'may': 1185, 'have': 884, 'begun': 189, 'research': 1610, 'facility': 716, '300': 24, 'yard': 2155, 'wuhan': 2153, 'wet': 2110, 'fish': 753, 'market': 1178, 'epidemic': 654, 'ha': 864, 'natural': 1273, 'origin': 1353, 'europe': 670, 'criminal': 448, 'negligence': 1282, 'preplanned': 1479, 'action': 57, 'learned': 1112, 'about': 44, 'created': 441, '2015': 16, 'they': 1943, 'decided': 494, 'pandemic': 1384, 'no': 1295, 'coincidence': 358, 'covid': 436, 'terror': 1921, 'uncertainty': 2018, 'trending': 1996, 'science': 1691, 'flatten': 755, 'curve': 464, 'become': 183, 'public': 1531, 'mantra': 1173, 'global': 832, 'fight': 744, 'what': 2111, 'will': 2125, 'month': 1239, 'our': 1361, 'society': 1780, 'only': 1338, 'certain': 312, 'thing': 1944, 'well': 2106, 'state': 1818, 'control': 407, 'rolling': 1646, 'update': 2033, 'on': 1334, 'scam': 1683, 'related': 1590, 'response': 1620, 'fighting': 745, 'disinformation': 564, 'escalating': 659, 'number': 1308, 'victim': 2058, 'across': 54, 'prof': 1501, 'that': 1928, 'merely': 1203, 'recurring': 1578, 'strain': 1842, 'seasonal': 1697, 'influenza': 1006, 'while': 2117, 'eu': 668, 'aim': 83, 'work': 2138, 'cooperatively': 411, 'constructively': 396, 'it': 1061, 'neighbour': 1284, 'we': 2094, 'always': 104, 'disclose': 552, 'harmful': 881, 'source': 1792, 'link': 1135, 'between': 201, '5g': 32, 'technology': 1913, 'one': 1336, 'using': 2041, 'crisis': 449, 'excuse': 686, 'impose': 985, 'mass': 1180, 'vaccination': 2045, 'supported': 1877, 'member': 1199, 'investment': 1048, 'signal': 1753, 'collapse': 362, 'schengen': 1689, 'migrant': 1212, 'bringing': 254, 'expert': 695, 'dismiss': 565, 'claim': 338, 'wireless': 2130, 'novel': 1306, 'commission': 368, 'creates': 442, 'fi ...
# [7.28039584 6.02763287 6.18178355 ... 6.18178355 7.28039584 6.87493073]
# (1, 2171)
# [[0. 0. 0. ... 0. 0. 0.]]

# %%
# list of text documents
text_label = final_df['label'].tolist()
# create the transform
vectorizer = TfidfVectorizer()
# tokenize and build vocab
vectorizer.fit(text_label)
# summarize
print(vectorizer.vocabulary_)
print(vectorizer.idf_)
# encode document
vector_label = vectorizer.transform([text[0]])
# summarize encoded vector
print(vector_label.shape)
print(vector_label.toarray())
# Out:
# {'fake': 0, 'genuine': 1}
# [1.7873344  1.60535583]
# (1, 2)
# [[0. 0.]]

# %% [markdown]
# ### Two classes for this dataset
#
# There are two labels one is Genuine and other is Fake, here one can see slight class imbalance, we have more Genuine results than Fake.

# %%
final_df['label'].value_counts()
# Out:
# GENUINE    582
# FAKE       485
# Name: label, dtype: int64

# %% [markdown]
# ### Combining Article content and Title of article
#
# Joining text and title of the articles

# %%
final_df['total']=final_df['text_clean']+' '+final_df['title_clean']

# %%
final_df['total'] = final_df['total'].str.replace('[^\w\s]','')
final_df['total'] = final_df['total'].str.lower()

# %%
final_df['total'][0]
# Out:
# 'you just need to add water and the drug and vaccine are ready to be administered there are two part to the kit one hold pellet containing the chemical machinery that synthesis the end product and the other hold pellet containing instruction that telll the drug which compound to create mix two part together in a chosen combination add water and the treatment is ready due to the recent outbreak for the coronavirus covid19 the world health organization is giving away vaccine kit just pay 495 for shipping'

# %%
y=final_df.label
y
# Out:
# 0          FAKE
# 9       GENUINE
# 14      GENUINE
# 16      GENUINE
# 17      GENUINE
#          ...
# 1159    GENUINE
# 1160    GENUINE
# 1161    GENUINE
# 1162    GENUINE
# 1163    GENUINE
# Name: label, Length: 1067, dtype: object

# %% [markdown]
# ### Features
#
# This project uses combined features like title of the article and text of the article. Train and Test split of 90 and 10% respectively.

# %%
features = final_df['total']

# %%
X_train, X_test, y_train, y_test = train_test_split(features, y, test_size=0.1,random_state=42)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (960,) (960,)
# (107,) (107,)

# %% [markdown]
# #### Tranforming splitted features into TfIdf vector

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(stop_words='english', max_df=0.80)  
tfidf_train = tfidf_vectorizer.fit_transform(X_train) 
tfidf_test = tfidf_vectorizer.transform(X_test)

# %% [markdown]
# ## Random Forest Classifier
#
# This part of this project uses Random Forest classifier for this binary classification. Random search cross validation is used to get best parameters to train the model and make predictions.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import RandomizedSearchCV
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 700, num = 50)]
max_features = ['auto', 'log2']  # Number of features to consider at every split
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]   # Maximum number of levels in tree
max_depth.append(None)
min_samples_split = [2, 5, 10]  # Minimum number of samples required to split a node
min_samples_leaf = [1, 4, 10]    # Minimum number of samples required at each leaf node
bootstrap = [True, False]       # Method of selecting samples for training each tree
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'max_leaf_nodes': [None] + list(np.linspace(10, 50, 500).astype(int)),
               'bootstrap': bootstrap}

# %%
# Create base model to tune
rf = RandomForestClassifier(oob_score=True)
# Create random search model and fit the data
rf_random = RandomizedSearchCV(
                        estimator = rf,
                        param_distributions = random_grid,
                        n_iter = 100, cv = 3,
                        verbose=2, random_state=42, 
                        scoring='roc_auc')
rf_random.fit(tfidf_train, y_train)
rf_random.best_params_
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] n_estimators=565, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=29, max_features=auto, max_depth=30, bootstrap=False
# [CV]  n_estimators=565, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=29, max_features=auto, max_depth=30, bootstrap=False, total=   0.0s
# [CV] n_estimators=565, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=29, max_features=auto, max_depth=30, bootstrap=False
# [CV]  n_estimators=565, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=29, max_features=auto, max_depth=30, bootstrap=False, total=   0.0s
# [CV] n_estimators=565, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=29, max_features=auto, max_depth=30, bootstrap=False
# [CV]  n_estimators=565, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=29, max_features=auto, max_depth=30, bootstrap=False, total=   0.0s
# [CV] n_estimators=516, min_samples_split=10, min_samples_leaf=10, max_leaf_nodes=12, max_features=log2, max_depth=30, bootstrap=False
# [CV]  n_estimators=516, min_samples_split=10, min_samples_leaf=10, max_leaf_nodes=12, max_features=log2, max_depth=30, bootstrap=False, total=   0.0s
# [CV] n_estimators=516, min_samples_split=10, min_samples_leaf=10, max_leaf_nodes=12, max_features=log2, max_depth=30, bootstrap=False
# [CV]  n_estimators=516, min_samples_split=10, min_samples_leaf=10, max_leaf_nodes=12, max_features=log2, max_depth=30, bootstrap=False, total=   0.0s
# [CV] n_estimators=516, min_samples_split=10, min_samples_leaf=10, max_leaf_nodes=12, max_features=log2, max_depth=30, bootstrap=False
# [CV]  n_estimators=516, min_samples_split=10, min_samples_leaf=10, max_leaf_nodes=12, max_features=log2, max_depth=30, bootstrap=False, total=   0.0s
# [CV] n_estimators=112, min_samples_split=2, min_samples_leaf=1, max_leaf_nodes=38, max_features=auto, max_depth=110, bootstrap=False
# [CV]  n_estimators=112, min_samples_split=2, min_samples_leaf=1, max_leaf_nodes=38, max_features=auto, max_depth=110, bootstrap=False, total=   0.0s
# [CV] n_estimators=112, min_samples_split=2, min_samples_leaf=1, max_leaf_nodes=38, max_features=auto, max_depth=110, bootstrap=False
# [CV]  n_estimators=112, min_samples_split=2, min_samples_leaf=1, max_leaf_nodes=38, max_features=auto, max_depth=110, bootstrap=False, total=   0.0s
# [CV] n_estimators=112, min_samples_split=2, min_samples_leaf=1, max_leaf_nodes=38, max_features=auto, max_depth=110, bootstrap=False
# [CV]  n_estimators=112, min_samples_split=2, min_samples_leaf=1, max_leaf_nodes=38, max_features=auto, max_depth=110, bootstrap=False, total=   0.0s
# [CV] n_estimators=369, min_samples_split=2, min_samples_leaf=10, max_leaf_nodes=13, max_features=log2, max_depth=100, bootstrap=True
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV]  n_estimators=369, min_samples_split=2, min_samples_leaf=10, max_leaf_nodes=13, max_features=log2, max_depth=100, bootstrap=True, total=   1.0s
# [CV] n_estimators=369, min_samples_split=2, min_samples_leaf=10, max_leaf_nodes=13, max_features=log2, max_depth=100, bootstrap=True
# [CV]  n_estimators=369, min_samples_split=2, min_samples_leaf=10, max_leaf_nodes=13, max_features=log2, max_depth=100, bootstrap=True, total=   1.0s
# [CV] n_estimators=369, min_samples_split=2, min_samples_leaf=10, max_leaf_nodes=13, max_features=log2, max_depth=100, bootstrap=True
# [CV]  n_estimators=369, min_samples_split=2, min_samples_leaf=10, max_leaf_nodes=13, max_features=log2, max_depth=100, bootstrap=True, total=   1.0s
# [CV] n_estimators=577, min_samples_split=5, min_samples_leaf=4, max_leaf_nodes=46, max_features=log2, max_depth=50, bootstrap=True
# [CV]  n_estimators=577, min_samples_split=5, min_samples_leaf=4, max_leaf_nodes=46, max_features=log2, max_depth=50, bootstrap=True, total=   1.6s
# [CV] n_estimators=577, min_samples_split=5, min_samples_leaf=4, max_leaf_nodes=46, max_features=log2, max_depth=50, bootstrap=True
# [CV]  n_estimators=577, min_samples_split=5, min_samples_leaf=4, max_leaf_nodes=46, max_features=log2, max_depth=50, bootstrap=True, total=   1.6s
# [CV] n_estimators=577, min_samples_split=5, min_samples_leaf=4, max_leaf_nodes=46, max_features=log2, max_depth=50, bootstrap=True
# [CV]  n_estimators=577, min_samples_split=5, min_samples_leaf=4, max_leaf_nodes=46, max_features=log2, max_depth=50, bootstrap=True, total=   1.6s
# [CV] n_estimators=271, min_samples_split=10, min_samples_leaf=1, max_leaf_nodes=16, max_features=auto, max_depth=110, bootstrap=False
# [CV]  n_estimators=271, min_samples_split=10, min_samples_leaf=1, max_leaf_nodes=16, max_features=auto, max_depth=110, bootstrap=False, total=   0.0s
# [CV] n_estimators=271, min_samples_split=10, min_samples_leaf=1, max_leaf_nodes=16, max_features=auto, max_depth=110, bootstrap=False
# [CV]  n_estimators=271, min_samples_split=10, min_samples_leaf=1, max_leaf_nodes=16, max_features=auto, max_depth=110, bootstrap=False, total=   0.0s
# [CV] n_estimators=271, min_samples_split=10, min_samples_leaf=1, max_leaf_nodes=16, max_features=auto, max_depth=110, bootstrap=False
# [CV]  n_estimators=271, min_samples_split=10, min_samples_leaf=1, max_leaf_nodes=16, max_features=auto, max_depth=110, bootstrap=False, total=   0.0s
# [CV] n_estimators=491, min_samples_split=10, min_samples_leaf=10, max_leaf_nodes=19, max_features=auto, max_depth=100, bootstrap=False
# [CV]  n_estimators=491, min_samples_split=10, min_samples_leaf=10, max_leaf_nodes=19, max_features=auto, max_depth=100, bootstrap=False, total=   0.0s
# [CV] n_estimators=491, min_samples_split=10, min_samples_leaf=10, max_leaf_nodes=19, max_features=auto, max_depth=100, bootstrap=False
# [CV]  n_estimators=491, min_samples_split=10, min_samples_leaf=10, max_leaf_nodes=19, max_features=auto, max_depth=100, bootstrap=False, total=   0.0s
# [CV] n_estimators=491, min_samples_split=10, min_samples_leaf=10, max_leaf_nodes=19, max_features=auto, max_depth=100, bootstrap=False
# [CV]  n_estimators=491, min_samples_split=10, min_samples_leaf=10, max_leaf_nodes=19, max_features=auto, max_depth=100, bootstrap=False, total=   0.0s
# [CV] n_estimators=246, min_samples_split=2, min_samples_leaf=4, max_leaf_nodes=48, max_features=log2, max_depth=40, bootstrap=False
# [CV]  n_estimators=246, min_samples_split=2, min_samples_leaf=4, max_leaf_nodes=48, max_features=log2, max_depth=40, bootstrap=False, total=   0.0s
# [CV] n_estimators=246, min_samples_split=2, min_samples_leaf=4, max_leaf_nodes=48, max_features=log2, max_depth=40, bootstrap=False
# [CV]  n_estimators=246, min_samples_split=2, min_samples_leaf=4, max_leaf_nodes=48, max_features=log2, max_depth=40, bootstrap=False, total=   0.0s
# [CV] n_estimators=246, min_samples_split=2, min_samples_leaf=4, max_leaf_nodes=48, max_features=log2, max_depth=40, bootstrap=False
# [CV]  n_estimators=246, min_samples_split=2, min_samples_leaf=4, max_leaf_nodes=48, max_features=log2, max_depth=40, bootstrap=False, total=   0.0s
# [CV] n_estimators=332, min_samples_split=2, min_samples_leaf=10, max_leaf_nodes=38, max_features=auto, max_depth=100, bootstrap=False
# [CV]  n_estimators=332, min_samples_split=2, min_samples_leaf=10, max_leaf_nodes=38, max_features=auto, max_depth=100, bootstrap=False, total=   0.0s
# [CV] n_estimators=332, min_samples_split=2, min_samples_leaf=10, max_leaf_nodes=38, max_features=auto, max_depth=100, bootstrap=False
# [CV]  n_estimators=332, min_samples_split=2, min_samples_leaf=10, max_leaf_nodes=38, max_features=auto, max_depth=100, bootstrap=False, total=   0.0s
# [CV] n_estimators=332, min_samples_split=2, min_samples_leaf=10, max_leaf_nodes=38, max_features=auto, max_depth=100, bootstrap=False
# [CV]  n_estimators=332, min_samples_split=2, min_samples_leaf=10, max_leaf_nodes=38, max_features=auto, max_depth=100, bootstrap=False, total=   0.0s
# [CV] n_estimators=357, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=43, max_features=log2, max_depth=100, bootstrap=True
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV]  n_estimators=357, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=43, max_features=log2, max_depth=100, bootstrap=True, total=   0.9s
# [CV] n_estimators=357, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=43, max_features=log2, max_depth=100, bootstrap=True
# [CV]  n_estimators=357, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=43, max_features=log2, max_depth=100, bootstrap=True, total=   0.9s
# [CV] n_estimators=357, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=43, max_features=log2, max_depth=100, bootstrap=True
# [CV]  n_estimators=357, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=43, max_features=log2, max_depth=100, bootstrap=True, total=   0.9s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_leaf_nodes=37, max_features=auto, max_depth=None, bootstrap=False
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_leaf_nodes=37, max_features=auto, max_depth=None, bootstrap=False, total=   0.0s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_leaf_nodes=37, max_features=auto, max_depth=None, bootstrap=False
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_leaf_nodes=37, max_features=auto, max_depth=None, bootstrap=False, total=   0.0s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_leaf_nodes=37, max_features=auto, max_depth=None, bootstrap=False
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=1, max_leaf_nodes=37, max_features=auto, max_depth=None, bootstrap=False, total=   0.0s
# [CV] n_estimators=332, min_samples_split=10, min_samples_leaf=4, max_leaf_nodes=12, max_features=auto, max_depth=110, bootstrap=True
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV]  n_estimators=332, min_samples_split=10, min_samples_leaf=4, max_leaf_nodes=12, max_features=auto, max_depth=110, bootstrap=True, total=   1.2s
# [CV] n_estimators=332, min_samples_split=10, min_samples_leaf=4, max_leaf_nodes=12, max_features=auto, max_depth=110, bootstrap=True
# [CV]  n_estimators=332, min_samples_split=10, min_samples_leaf=4, max_leaf_nodes=12, max_features=auto, max_depth=110, bootstrap=True, total=   1.2s
# [CV] n_estimators=332, min_samples_split=10, min_samples_leaf=4, max_leaf_nodes=12, max_features=auto, max_depth=110, bootstrap=True
# [CV]  n_estimators=332, min_samples_split=10, min_samples_leaf=4, max_leaf_nodes=12, max_features=auto, max_depth=110, bootstrap=True, total=   1.3s
# [CV] n_estimators=124, min_samples_split=10, min_samples_leaf=1, max_leaf_nodes=43, max_features=auto, max_depth=50, bootstrap=False
# [CV]  n_estimators=124, min_samples_split=10, min_samples_leaf=1, max_leaf_nodes=43, max_features=auto, max_depth=50, bootstrap=False, total=   0.0s
# [CV] n_estimators=124, min_samples_split=10, min_samples_leaf=1, max_leaf_nodes=43, max_features=auto, max_depth=50, bootstrap=False
# [CV]  n_estimators=124, min_samples_split=10, min_samples_leaf=1, max_leaf_nodes=43, max_features=auto, max_depth=50, bootstrap=False, total=   0.0s
# [CV] n_estimators=124, min_samples_split=10, min_samples_leaf=1, max_leaf_nodes=43, max_features=auto, max_depth=50, bootstrap=False
# [CV]  n_estimators=124, min_samples_split=10, min_samples_leaf=1, max_leaf_nodes=43, max_features=auto, max_depth=50, bootstrap=False, total=   0.0s
# [CV] n_estimators=161, min_samples_split=2, min_samples_leaf=1, max_leaf_nodes=13, max_features=auto, max_depth=None, bootstrap=True
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV]  n_estimators=161, min_samples_split=2, min_samples_leaf=1, max_leaf_nodes=13, max_features=auto, max_depth=None, bootstrap=True, total=   0.6s
# [CV] n_estimators=161, min_samples_split=2, min_samples_leaf=1, max_leaf_nodes=13, max_features=auto, max_depth=None, bootstrap=True
# [CV]  n_estimators=161, min_samples_split=2, min_samples_leaf=1, max_leaf_nodes=13, max_features=auto, max_depth=None, bootstrap=True, total=   0.6s
# [CV] n_estimators=161, min_samples_split=2, min_samples_leaf=1, max_leaf_nodes=13, max_features=auto, max_depth=None, bootstrap=True
# [CV]  n_estimators=161, min_samples_split=2, min_samples_leaf=1, max_leaf_nodes=13, max_features=auto, max_depth=None, bootstrap=True, total=   0.6s
# [CV] n_estimators=602, min_samples_split=2, min_samples_leaf=4, max_leaf_nodes=43, max_features=log2, max_depth=40, bootstrap=True
# [CV]  n_estimators=602, min_samples_split=2, min_samples_leaf=4, max_leaf_nodes=43, max_features=log2, max_depth=40, bootstrap=True, total=   1.6s
# [CV] n_estimators=602, min_samples_split=2, min_samples_leaf=4, max_leaf_nodes=43, max_features=log2, max_depth=40, bootstrap=True
# [CV]  n_estimators=602, min_samples_split=2, min_samples_leaf=4, max_leaf_nodes=43, max_features=log2, max_depth=40, bootstrap=True, total=   1.6s
# [CV] n_estimators=602, min_samples_split=2, min_samples_leaf=4, max_leaf_nodes=43, max_features=log2, max_depth=40, bootstrap=True
# [CV]  n_estimators=602, min_samples_split=2, min_samples_leaf=4, max_leaf_nodes=43, max_features=log2, max_depth=40, bootstrap=True, total=   1.6s
# [CV] n_estimators=381, min_samples_split=5, min_samples_leaf=4, max_leaf_nodes=12, max_features=auto, max_depth=110, bootstrap=True
# [CV]  n_estimators=381, min_samples_split=5, min_samples_leaf=4, max_leaf_nodes=12, max_features=auto, max_depth=110, bootstrap=True, total=   1.4s
# [CV] n_estimators=381, min_samples_split=5, min_samples_leaf=4, max_leaf_nodes=12, max_features=auto, max_depth=110, bootstrap=True
# [CV]  n_estimators=381, min_samples_split=5, min_samples_leaf=4, max_leaf_nodes=12, max_features=auto, max_depth=110, bootstrap=True, total=   1.4s
# [CV] n_estimators=381, min_samples_split=5, min_samples_leaf=4, max_leaf_nodes=12, max_features=auto, max_depth=110, bootstrap=True
# [CV]  n_estimators=381, min_samples_split=5, min_samples_leaf=4, max_leaf_nodes=12, max_features=auto, max_depth=110, bootstrap=True, total=   1.4s
# [CV] n_estimators=430, min_samples_split=5, min_samples_leaf=4, max_leaf_nodes=38, max_features=auto, max_depth=20, bootstrap=False
# [CV]  n_estimators=430, min_samples_split=5, min_samples_leaf=4, max_leaf_nodes=38, max_features=auto, max_depth=20, bootstrap=False, total=   0.0s
# [CV] n_estimators=430, min_samples_split=5, min_samples_leaf=4, max_leaf_nodes=38, max_features=auto, max_depth=20, bootstrap=False
# [CV]  n_estimators=430, min_samples_split=5, min_samples_leaf=4, max_leaf_nodes=38, max_features=auto, max_depth=20, bootstrap=False, total=   0.0s
# [CV] n_estimators=430, min_samples_split=5, min_samples_leaf=4, max_leaf_nodes=38, max_features=auto, max_depth=20, bootstrap=False
# [CV]  n_estimators=430, min_samples_split=5, min_samples_leaf=4, max_leaf_nodes=38, max_features=auto, max_depth=20, bootstrap=False, total=   0.0s
# [CV] n_estimators=332, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=43, max_features=auto, max_depth=80, bootstrap=True
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV]  n_estimators=332, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=43, max_features=auto, max_depth=80, bootstrap=True, total=   1.2s
# [CV] n_estimators=332, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=43, max_features=auto, max_depth=80, bootstrap=True
# [CV]  n_estimators=332, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=43, max_features=auto, max_depth=80, bootstrap=True, total=   1.2s
# [CV] n_estimators=332, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=43, max_features=auto, max_depth=80, bootstrap=True
# [CV]  n_estimators=332, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=43, max_features=auto, max_depth=80, bootstrap=True, total=   1.2s
# [CV] n_estimators=112, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=38, max_features=auto, max_depth=90, bootstrap=False
# [CV]  n_estimators=112, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=38, max_features=auto, max_depth=90, bootstrap=False, total=   0.0s
# [CV] n_estimators=112, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=38, max_features=auto, max_depth=90, bootstrap=False
# [CV]  n_estimators=112, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=38, max_features=auto, max_depth=90, bootstrap=False, total=   0.0s
# [CV] n_estimators=112, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=38, max_features=auto, max_depth=90, bootstrap=False
# [CV]  n_estimators=112, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=38, max_features=auto, max_depth=90, bootstrap=False, total=   0.0s
# [CV] n_estimators=161, min_samples_split=2, min_samples_leaf=10, max_leaf_nodes=28, max_features=auto, max_depth=10, bootstrap=True
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV]  n_estimators=161, min_samples_split=2, min_samples_leaf=10, max_leaf_nodes=28, max_features=auto, max_depth=10, bootstrap=True, total=   0.6s
# [CV] n_estimators=161, min_samples_split=2, min_samples_leaf=10, max_leaf_nodes=28, max_features=auto, max_depth=10, bootstrap=True
# [CV]  n_estimators=161, min_samples_split=2, min_samples_leaf=10, max_leaf_nodes=28, max_features=auto, max_depth=10, bootstrap=True, total=   0.6s
# [CV] n_estimators=161, min_samples_split=2, min_samples_leaf=10, max_leaf_nodes=28, max_features=auto, max_depth=10, bootstrap=True
# [CV]  n_estimators=161, min_samples_split=2, min_samples_leaf=10, max_leaf_nodes=28, max_features=auto, max_depth=10, bootstrap=True, total=   0.6s
# [CV] n_estimators=124, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=34, max_features=log2, max_depth=30, bootstrap=True
# [CV]  n_estimators=124, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=34, max_features=log2, max_depth=30, bootstrap=True, total=   0.4s
# [CV] n_estimators=124, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=34, max_features=log2, max_depth=30, bootstrap=True
# [CV]  n_estimators=124, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=34, max_features=log2, max_depth=30, bootstrap=True, total=   0.4s
# [CV] n_estimators=124, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=34, max_features=log2, max_depth=30, bootstrap=True
# [CV]  n_estimators=124, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=34, max_features=log2, max_depth=30, bootstrap=True, total=   0.4s
# [CV] n_estimators=504, min_samples_split=10, min_samples_leaf=4, max_leaf_nodes=25, max_features=log2, max_depth=100, bootstrap=False
# [CV]  n_estimators=504, min_samples_split=10, min_samples_leaf=4, max_leaf_nodes=25, max_features=log2, max_depth=100, bootstrap=False, total=   0.0s
# [CV] n_estimators=504, min_samples_split=10, min_samples_leaf=4, max_leaf_nodes=25, max_features=log2, max_depth=100, bootstrap=False
# [CV]  n_estimators=504, min_samples_split=10, min_samples_leaf=4, max_leaf_nodes=25, max_features=log2, max_depth=100, bootstrap=False, total=   0.0s
# [CV] n_estimators=504, min_samples_split=10, min_samples_leaf=4, max_leaf_nodes=25, max_features=log2, max_depth=100, bootstrap=False
# [CV]  n_estimators=504, min_samples_split=10, min_samples_leaf=4, max_leaf_nodes=25, max_features=log2, max_depth=100, bootstrap=False, total=   0.0s
# [CV] n_estimators=577, min_samples_split=2, min_samples_leaf=4, max_leaf_nodes=14, max_features=log2, max_depth=10, bootstrap=False
# [CV]  n_estimators=577, min_samples_split=2, min_samples_leaf=4, max_leaf_nodes=14, max_features=log2, max_depth=10, bootstrap=False, total=   0.0s
# [CV] n_estimators=577, min_samples_split=2, min_samples_leaf=4, max_leaf_nodes=14, max_features=log2, max_depth=10, bootstrap=False
# [CV]  n_estimators=577, min_samples_split=2, min_samples_leaf=4, max_leaf_nodes=14, max_features=log2, max_depth=10, bootstrap=False, total=   0.0s
# [CV] n_estimators=577, min_samples_split=2, min_samples_leaf=4, max_leaf_nodes=14, max_features=log2, max_depth=10, bootstrap=False
# [CV]  n_estimators=577, min_samples_split=2, min_samples_leaf=4, max_leaf_nodes=14, max_features=log2, max_depth=10, bootstrap=False, total=   0.0s
# [CV] n_estimators=455, min_samples_split=10, min_samples_leaf=4, max_leaf_nodes=10, max_features=log2, max_depth=100, bootstrap=False
# [CV]  n_estimators=455, min_samples_split=10, min_samples_leaf=4, max_leaf_nodes=10, max_features=log2, max_depth=100, bootstrap=False, total=   0.0s
# [CV] n_estimators=455, min_samples_split=10, min_samples_leaf=4, max_leaf_nodes=10, max_features=log2, max_depth=100, bootstrap=False
# [CV]  n_estimators=455, min_samples_split=10, min_samples_leaf=4, max_leaf_nodes=10, max_features=log2, max_depth=100, bootstrap=False, total=   0.0s
# [CV] n_estimators=455, min_samples_split=10, min_samples_leaf=4, max_leaf_nodes=10, max_features=log2, max_depth=100, bootstrap=False
# [CV]  n_estimators=455, min_samples_split=10, min_samples_leaf=4, max_leaf_nodes=10, max_features=log2, max_depth=100, bootstrap=False, total=   0.0s
# [CV] n_estimators=687, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=20, max_features=log2, max_depth=90, bootstrap=False
# [CV]  n_estimators=687, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=20, max_features=log2, max_depth=90, bootstrap=False, total=   0.0s
# [CV] n_estimators=687, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=20, max_features=log2, max_depth=90, bootstrap=False
# [CV]  n_estimators=687, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=20, max_features=log2, max_depth=90, bootstrap=False, total=   0.0s
# [CV] n_estimators=687, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=20, max_features=log2, max_depth=90, bootstrap=False
# [CV]  n_estimators=687, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=20, max_features=log2, max_depth=90, bootstrap=False, total=   0.0s
# [CV] n_estimators=295, min_samples_split=2, min_samples_leaf=4, max_leaf_nodes=28, max_features=log2, max_depth=10, bootstrap=False
# [CV]  n_estimators=295, min_samples_split=2, min_samples_leaf=4, max_leaf_nodes=28, max_features=log2, max_depth=10, bootstrap=False, total=   0.0s
# [CV] n_estimators=295, min_samples_split=2, min_samples_leaf=4, max_leaf_nodes=28, max_features=log2, max_depth=10, bootstrap=False
# [CV]  n_estimators=295, min_samples_split=2, min_samples_leaf=4, max_leaf_nodes=28, max_features=log2, max_depth=10, bootstrap=False, total=   0.0s
# [CV] n_estimators=295, min_samples_split=2, min_samples_leaf=4, max_leaf_nodes=28, max_features=log2, max_depth=10, bootstrap=False
# [CV]  n_estimators=295, min_samples_split=2, min_samples_leaf=4, max_leaf_nodes=28, max_features=log2, max_depth=10, bootstrap=False, total=   0.0s
# [CV] n_estimators=589, min_samples_split=10, min_samples_leaf=10, max_leaf_nodes=18, max_features=log2, max_depth=None, bootstrap=False
# [CV]  n_estimators=589, min_samples_split=10, min_samples_leaf=10, max_leaf_nodes=18, max_features=log2, max_depth=None, bootstrap=False, total=   0.0s
# [CV] n_estimators=589, min_samples_split=10, min_samples_leaf=10, max_leaf_nodes=18, max_features=log2, max_depth=None, bootstrap=False
# [CV]  n_estimators=589, min_samples_split=10, min_samples_leaf=10, max_leaf_nodes=18, max_features=log2, max_depth=None, bootstrap=False, total=   0.0s
# [CV] n_estimators=589, min_samples_split=10, min_samples_leaf=10, max_leaf_nodes=18, max_features=log2, max_depth=None, bootstrap=False
# [CV]  n_estimators=589, min_samples_split=10, min_samples_leaf=10, max_leaf_nodes=18, max_features=log2, max_depth=None, bootstrap=False, total=   0.0s
# [CV] n_estimators=589, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=14, max_features=log2, max_depth=20, bootstrap=False
# [CV]  n_estimators=589, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=14, max_features=log2, max_depth=20, bootstrap=False, total=   0.0s
# [CV] n_estimators=589, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=14, max_features=log2, max_depth=20, bootstrap=False
# [CV]  n_estimators=589, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=14, max_features=log2, max_depth=20, bootstrap=False, total=   0.0s
# [CV] n_estimators=589, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=14, max_features=log2, max_depth=20, bootstrap=False
# [CV]  n_estimators=589, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=14, max_features=log2, max_depth=20, bootstrap=False, total=   0.0s
# [CV] n_estimators=577, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=47, max_features=auto, max_depth=110, bootstrap=True
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
# ...
# [CV]  n_estimators=369, min_samples_split=2, min_samples_leaf=10, max_leaf_nodes=22, max_features=auto, max_depth=40, bootstrap=True, total=   1.3s
# [CV] n_estimators=369, min_samples_split=2, min_samples_leaf=10, max_leaf_nodes=22, max_features=auto, max_depth=40, bootstrap=True
# [CV]  n_estimators=369, min_samples_split=2, min_samples_leaf=10, max_leaf_nodes=22, max_features=auto, max_depth=40, bootstrap=True, total=   1.3s
# [CV] n_estimators=516, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=18, max_features=auto, max_depth=10, bootstrap=True
# [CV]  n_estimators=516, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=18, max_features=auto, max_depth=10, bootstrap=True, total=   1.7s
# [CV] n_estimators=516, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=18, max_features=auto, max_depth=10, bootstrap=True
# [CV]  n_estimators=516, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=18, max_features=auto, max_depth=10, bootstrap=True, total=   1.7s
# [CV] n_estimators=516, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=18, max_features=auto, max_depth=10, bootstrap=True
# [CV]  n_estimators=516, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=18, max_features=auto, max_depth=10, bootstrap=True, total=   1.7s
# [CV] n_estimators=442, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=44, max_features=log2, max_depth=None, bootstrap=False
# [CV]  n_estimators=442, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=44, max_features=log2, max_depth=None, bootstrap=False, total=   0.0s
# [CV] n_estimators=442, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=44, max_features=log2, max_depth=None, bootstrap=False
# [CV]  n_estimators=442, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=44, max_features=log2, max_depth=None, bootstrap=False, total=   0.0s
# [CV] n_estimators=442, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=44, max_features=log2, max_depth=None, bootstrap=False
# [CV]  n_estimators=442, min_samples_split=5, min_samples_leaf=10, max_leaf_nodes=44, max_features=log2, max_depth=None, bootstrap=False, total=   0.0s
# [CV] n_estimators=320, min_samples_split=10, min_samples_leaf=1, max_leaf_nodes=13, max_features=log2, max_depth=30, bootstrap=False
# [CV]  n_estimators=320, min_samples_split=10, min_samples_leaf=1, max_leaf_nodes=13, max_features=log2, max_depth=30, bootstrap=False, total=   0.0s
# [CV] n_estimators=320, min_samples_split=10, min_samples_leaf=1, max_leaf_nodes=13, max_features=log2, max_depth=30, bootstrap=False
# [CV]  n_estimators=320, min_samples_split=10, min_samples_leaf=1, max_leaf_nodes=13, max_features=log2, max_depth=30, bootstrap=False, total=   0.0s
# [CV] n_estimators=320, min_samples_split=10, min_samples_leaf=1, max_leaf_nodes=13, max_features=log2, max_depth=30, bootstrap=False
# [CV]  n_estimators=320, min_samples_split=10, min_samples_leaf=1, max_leaf_nodes=13, max_features=log2, max_depth=30, bootstrap=False, total=   0.0s
# [CV] n_estimators=516, min_samples_split=2, min_samples_leaf=1, max_leaf_nodes=36, max_features=auto, max_depth=40, bootstrap=True
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV]  n_estimators=516, min_samples_split=2, min_samples_leaf=1, max_leaf_nodes=36, max_features=auto, max_depth=40, bootstrap=True, total=   2.3s
# [CV] n_estimators=516, min_samples_split=2, min_samples_leaf=1, max_leaf_nodes=36, max_features=auto, max_depth=40, bootstrap=True
# [CV]  n_estimators=516, min_samples_split=2, min_samples_leaf=1, max_leaf_nodes=36, max_features=auto, max_depth=40, bootstrap=True, total=   2.2s
# [CV] n_estimators=516, min_samples_split=2, min_samples_leaf=1, max_leaf_nodes=36, max_features=auto, max_depth=40, bootstrap=True
# [CV]  n_estimators=516, min_samples_split=2, min_samples_leaf=1, max_leaf_nodes=36, max_features=auto, max_depth=40, bootstrap=True, total=   2.3s
# [CV] n_estimators=332, min_samples_split=10, min_samples_leaf=4, max_leaf_nodes=45, max_features=log2, max_depth=50, bootstrap=True
# [CV]  n_estimators=332, min_samples_split=10, min_samples_leaf=4, max_leaf_nodes=45, max_features=log2, max_depth=50, bootstrap=True, total=   0.9s
# [CV] n_estimators=332, min_samples_split=10, min_samples_leaf=4, max_leaf_nodes=45, max_features=log2, max_depth=50, bootstrap=True
# [CV]  n_estimators=332, min_samples_split=10, min_samples_leaf=4, max_leaf_nodes=45, max_features=log2, max_depth=50, bootstrap=True, total=   0.9s
# [CV] n_estimators=332, min_samples_split=10, min_samples_leaf=4, max_leaf_nodes=45, max_features=log2, max_depth=50, bootstrap=True
# [CV]  n_estimators=332, min_samples_split=10, min_samples_leaf=4, max_leaf_nodes=45, max_features=log2, max_depth=50, bootstrap=True, total=   0.8s
# [CV] n_estimators=332, min_samples_split=5, min_samples_leaf=4, max_leaf_nodes=41, max_features=auto, max_depth=40, bootstrap=False
# [CV]  n_estimators=332, min_samples_split=5, min_samples_leaf=4, max_leaf_nodes=41, max_features=auto, max_depth=40, bootstrap=False, total=   0.0s
# [CV] n_estimators=332, min_samples_split=5, min_samples_leaf=4, max_leaf_nodes=41, max_features=auto, max_depth=40, bootstrap=False
# [CV]  n_estimators=332, min_samples_split=5, min_samples_leaf=4, max_leaf_nodes=41, max_features=auto, max_depth=40, bootstrap=False, total=   0.0s
# [CV] n_estimators=332, min_samples_split=5, min_samples_leaf=4, max_leaf_nodes=41, max_features=auto, max_depth=40, bootstrap=False
# [CV]  n_estimators=332, min_samples_split=5, min_samples_leaf=4, max_leaf_nodes=41, max_features=auto, max_depth=40, bootstrap=False, total=   0.0s
# [CV] n_estimators=516, min_samples_split=10, min_samples_leaf=10, max_leaf_nodes=49, max_features=auto, max_depth=110, bootstrap=False
# [CV]  n_estimators=516, min_samples_split=10, min_samples_leaf=10, max_leaf_nodes=49, max_features=auto, max_depth=110, bootstrap=False, total=   0.0s
# [CV] n_estimators=516, min_samples_split=10, min_samples_leaf=10, max_leaf_nodes=49, max_features=auto, max_depth=110, bootstrap=False
# [CV]  n_estimators=516, min_samples_split=10, min_samples_leaf=10, max_leaf_nodes=49, max_features=auto, max_depth=110, bootstrap=False, total=   0.0s
# [CV] n_estimators=516, min_samples_split=10, min_samples_leaf=10, max_leaf_nodes=49, max_features=auto, max_depth=110, bootstrap=False
# [CV]  n_estimators=516, min_samples_split=10, min_samples_leaf=10, max_leaf_nodes=49, max_features=auto, max_depth=110, bootstrap=False, total=   0.0s
# [CV] n_estimators=651, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=38, max_features=log2, max_depth=40, bootstrap=True
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py", line 351, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV]  n_estimators=651, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=38, max_features=log2, max_depth=40, bootstrap=True, total=   2.1s
# [CV] n_estimators=651, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=38, max_features=log2, max_depth=40, bootstrap=True
# [CV]  n_estimators=651, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=38, max_features=log2, max_depth=40, bootstrap=True, total=   2.1s
# [CV] n_estimators=651, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=38, max_features=log2, max_depth=40, bootstrap=True
# [CV]  n_estimators=651, min_samples_split=5, min_samples_leaf=1, max_leaf_nodes=38, max_features=log2, max_depth=40, bootstrap=True, total=   2.1s
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:  4.2min finished
# {'n_estimators': 479,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_leaf_nodes': 43,
#  'max_features': 'auto',
#  'max_depth': None,
#  'bootstrap': True}

# %% [markdown]
# From the above results, we can see that the best parameters to train our model with are as shown below,
# ```
# {'n_estimators': 479,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_leaf_nodes': 43,
#  'max_features': 'auto',
#  'max_depth': None,
#  'bootstrap': True}
#
# ```
#
# We used these parameters to train our classifier and in addition to the above parameter, we also used gini criterion for the training purpose, gini criterion has been chosen considering the fact that it does not require logrithmic calculations hence computationally in-expensive as compared to entropy criterion.

# %%
classifier = RandomForestClassifier(n_estimators = 479,
     min_samples_split = 2,
     min_samples_leaf= 1,
     max_leaf_nodes= 43,
     max_features= 'auto',
     criterion = 'gini',
     max_depth= None,
     bootstrap = True)

# %%
classifier.fit(tfidf_train, y_train)
# Out:
# RandomForestClassifier(max_leaf_nodes=43, n_estimators=479)

# %%
y_pred_RF = classifier.predict(tfidf_test)
y_pred_RF[4]
# Out:
# 'FAKE'

# %%
cross_val_score(classifier, tfidf_train, y_train, cv=10)
# Out:
# array([0.85416667, 0.92708333, 0.875     , 0.84375   , 0.875     ,
#        0.875     , 0.875     , 0.88541667, 0.90625   , 0.86458333])

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

# %%
print("f1_Score_micro: ", f1_score(y_test, y_pred_RF, average="micro"))
print("f1_score_weighted", f1_score(y_test, y_pred_RF, average='weighted'))
# Out:
# f1_Score_micro:  0.9158878504672897
# f1_score_weighted 0.9159771335981515

# %%
print("Classification Report: \n", metrics.classification_report(y_test, y_pred_RF))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#         FAKE       0.90      0.91      0.91        47
#      GENUINE       0.93      0.92      0.92        60
#
#     accuracy                           0.92       107
#    macro avg       0.91      0.92      0.91       107
# weighted avg       0.92      0.92      0.92       107

# %%
cm = confusion_matrix(y_test, y_pred_RF)
import seaborn as sns

print("confusion matrix: \n", sns.heatmap(cm, annot = True))
# Out:
# confusion matrix:
#  AxesSubplot(0.125,0.125;0.62x0.755)

# %%
from pprint import pprint
print('Parameters currently in use:\n')
pprint(classifier.get_params())
# Out:
# Parameters currently in use:
#
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': 43,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 479,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}
